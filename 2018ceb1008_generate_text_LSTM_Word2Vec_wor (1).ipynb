# %%
from __future__ import print_function

import numpy as np
import gensim
import string

from keras.callbacks import LambdaCallback
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers import Dense, Activation
from keras.models import Sequential
from keras.utils.data_utils import get_file

print('\nFetching the text...')
url = 'https://ota.bodleian.ox.ac.uk/repository/xmlui/bitstream/handle/20.500.12024/5730/5730.txt'
path = get_file('tresure_island.txt', origin=url)

print('\nPreparing the sentences...')
max_sentence_len = 20
with open(path) as file_:
  docs = file_.readlines()
sentences = [[word for word in doc.lower().translate(string.punctuation).split()[:max_sentence_len]] for doc in docs]
print('Num sentences:', len(sentences))
print(sentences)

print('\nTraining word2vec...')
word_model = gensim.models.Word2Vec(sentences, size=100, min_count=1, window=5, iter=100)
pretrained_weights = word_model.wv.syn0
vocab_size, emdedding_size = pretrained_weights.shape
print('Result embedding shape:', pretrained_weights.shape)
print('Checking similar words:')
for word in ['american', 'evening', 'treasure', 'captain']:
  most_similar = ', '.join('%s (%.2f)' % (similar, dist) for similar, dist in word_model.most_similar(word)[:8])
  print('  %s -> %s' % (word, most_similar))

def word2idx(word):
  return word_model.wv.vocab[word].index
def idx2word(idx):
  return word_model.wv.index2word[idx]

print('\nPreparing the data for LSTM...')
train_x = np.zeros([len(sentences), max_sentence_len], dtype=np.int32)
train_y = np.zeros([len(sentences)], dtype=np.int32)
for i, sentence in enumerate(sentences):
  for t, word in enumerate(sentence[:-1]):
    train_x[i, t] = word2idx(word)
  train_y[i] = word2idx(sentence[-1])
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)

print('\nTraining LSTM...')
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=emdedding_size, weights=[pretrained_weights]))
model.add(LSTM(units=emdedding_size))
model.add(Dense(units=vocab_size))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

def sample(preds, temperature=1.0):
  if temperature <= 0:
    return np.argmax(preds)
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

def generate_next(text, num_generated=10):
  word_idxs = [word2idx(word) for word in text.lower().split()]
  for i in range(num_generated):
    prediction = model.predict(x=np.array(word_idxs))
    idx = sample(prediction[-1], temperature=0.7)
    word_idxs.append(idx)
  return ' '.join(idx2word(idx) for idx in word_idxs)

def on_epoch_end(epoch, _):
  print('\nGenerating text after epoch: %d' % epoch)
  texts = [
    'one',
    'classic',
    'i remember',
    'a',
  ]
  for text in texts:
    sample = generate_next(text)
    print('%s... -> %s' % (text, sample))

model.fit(train_x, train_y,
          batch_size=128,
          epochs=20,
          callbacks=[LambdaCallback(on_epoch_end=on_epoch_end)])
# Out:
# Fetching the text...
# Downloading data from https://ota.bodleian.ox.ac.uk/repository/xmlui/bitstream/handle/20.500.12024/5730/5730.txt
# 360448/358061 [==============================] - 0s 0us/step
#
# Preparing the sentences...
# Num sentences: 1419
# [['treasure', 'island+'], ['to', 's.l.o.,', 'an', 'american', 'gentleman', 'in', 'accordance', 'with', 'whose', 'classic', 'taste', 'the', 'following', 'narrative', 'has', 'been', 'designed,', 'it', 'is', 'now,'], ['to', 'the', 'hesitating', 'purchaser+'], ['if', 'sailor', 'tales', 'to', 'sailor', 'tunes,+'], ['storm', 'and', 'adventure,', 'heat', 'and', 'cold,+'], ['if', 'schooners,', 'islands,', 'and', 'maroons,+'], ['and', 'buccaneers,', 'and', 'buried', 'gold,+'], ['and', 'all', 'the', 'old', 'romance,', 'retold+'], ['exactly', 'in', 'the', 'ancient', 'way,+'], ['can', 'please,', 'as', 'me', 'they', 'pleased', 'of', 'old,+'], ['the', 'wiser', 'youngsters', 'of', 'today:+'], ['part', 'one—the', 'old', 'buccaneer+'], ['the', 'old', 'sea-dog', 'at', 'the', 'admiral', 'benbow+'], ['squire', 'trelawney,', 'dr.', 'livesey,', 'and', 'the', 'rest', 'of', 'these', 'gentlemen', 'having', 'asked', 'me', 'to', 'write', 'down', 'the', 'whole', 'particulars', 'about'], ['i', 'remember', 'him', 'as', 'if', 'it', 'were', 'yesterday,', 'as', 'he', 'came', 'plodding', 'to', 'the', 'inn', 'door,', 'his', 'sea-chest', 'following', 'behind'], ['"fifteen', 'men', 'on', 'the', 'dead', "man's", 'chest--+'], ['yo-ho-ho,', 'and', 'a', 'bottle', 'of', 'rum!"+'], ['in', 'the', 'high,', 'old', 'tottering', 'voice', 'that', 'seemed', 'to', 'have', 'been', 'tuned', 'and', 'broken', 'at', 'the', 'capstan', 'bars.', 'then', 'he'], ['"this', 'is', 'a', 'handy', 'cove,"', 'says', 'he', 'at', 'length;', '"and', 'a', 'pleasant', 'sittyated', 'grog-shop.', 'much', 'company,', 'mate?"+'], ['my', 'father', 'told', 'him', 'no,', 'very', 'little', 'company,', 'the', 'more', 'was', 'the', 'pity.+'], ['"well,', 'then,"', 'said', 'he,', '"this', 'is', 'the', 'berth', 'for', 'me.', 'here', 'you,', 'matey,"', 'he', 'cried', 'to', 'the', 'man', 'who', 'trundled'], ['and', 'indeed', 'bad', 'as', 'his', 'clothes', 'were', 'and', 'coarsely', 'as', 'he', 'spoke,', 'he', 'had', 'none', 'of', 'the', 'appearance', 'of', 'a'], ['he', 'was', 'a', 'very', 'silent', 'man', 'by', 'custom.', 'all', 'day', 'he', 'hung', 'round', 'the', 'cove', 'or', 'upon', 'the', 'cliffs', 'with'], ['how', 'that', 'personage', 'haunted', 'my', 'dreams,', 'i', 'need', 'scarcely', 'tell', 'you.', 'on', 'stormy', 'nights,', 'when', 'the', 'wind', 'shook', 'the', 'four'], ['but', 'though', 'i', 'was', 'so', 'terrified', 'by', 'the', 'idea', 'of', 'the', 'seafaring', 'man', 'with', 'one', 'leg,', 'i', 'was', 'far', 'less'], ['his', 'stories', 'were', 'what', 'frightened', 'people', 'worst', 'of', 'all.', 'dreadful', 'stories', 'they', 'were—about', 'hanging,', 'and', 'walking', 'the', 'plank,', 'and', 'storms'], ['in', 'one', 'way,', 'indeed,', 'he', 'bade', 'fair', 'to', 'ruin', 'us,', 'for', 'he', 'kept', 'on', 'staying', 'week', 'after', 'week,', 'and', 'at'], ['all', 'the', 'time', 'he', 'lived', 'with', 'us', 'the', 'captain', 'made', 'no', 'change', 'whatever', 'in', 'his', 'dress', 'but', 'to', 'buy', 'some'], ['he', 'was', 'only', 'once', 'crossed,', 'and', 'that', 'was', 'towards', 'the', 'end,', 'when', 'my', 'poor', 'father', 'was', 'far', 'gone', 'in', 'a'], ['"fifteen', 'men', 'on', 'the', 'dead', "man's", 'chest--+'], ['yo-ho-ho,', 'and', 'a', 'bottle', 'of', 'rum!+'], ['drink', 'and', 'the', 'devil', 'had', 'done', 'for', 'the', 'rest--+'], ['yo-ho-ho,', 'and', 'a', 'bottle', 'of', 'rum!"+'], ['at', 'first', 'i', 'had', 'supposed', '"the', 'dead', "man's", 'chest"', 'to', 'be', 'that', 'identical', 'big', 'box', 'of', 'his', 'upstairs', 'in', 'the'], ['"were', 'you', 'addressing', 'me,', 'sir?"', 'says', 'the', 'doctor;', 'and', 'when', 'the', 'ruffian', 'had', 'told', 'him,', 'with', 'another', 'oath,', 'that', 'this'], ['the', 'old', "fellow's", 'fury', 'was', 'awful.', 'he', 'sprang', 'to', 'his', 'feet,', 'drew', 'and', 'opened', 'a', "sailor's", 'clasp-knife,', 'and', 'balancing', 'it'], ['the', 'doctor', 'never', 'so', 'much', 'as', 'moved.', 'he', 'spoke', 'to', 'him', 'as', 'before ...
#
# Training word2vec...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
# Result embedding shape: (5209, 100)
# Checking similar words:
#   american -> s.l.o., (0.97), accordance (0.95), away.+ (0.92), instant (0.91), treasure-hunt—flint's (0.89), ebb-tide (0.88), youngsters (0.88), humility, (0.88)
#   evening -> idle, (0.80), trim (0.79), concern, (0.77), sealed (0.76), favour. (0.76), minds, (0.76), merry's (0.75), blundered (0.75)
#   treasure -> rear, (0.82), quiet (0.82), western (0.80), island. (0.80), report (0.80), clearing. (0.79), balls (0.79), inside (0.77)
#   captain -> "load (0.59), "well?" (0.58), fellow (0.54), doctor (0.53), smollett (0.53), chart (0.53), door. (0.50), return, (0.50)
#
# Preparing the data for LSTM...
# train_x shape: (1419, 20)
# train_y shape: (1419,)
#
# Training LSTM...
# Epoch 1/20
# 12/12 [==============================] - 31s 18ms/step - loss: 8.5190
#
# Generating text after epoch: 0
# one... -> one me. son. steel. visibly way, coming unarmed, escape berth five
# classic... -> classic district, care," "you'll minds, strike see "well?" tore breakfast pleasant,
# i remember... -> i remember ruffian coming cap'n "perfectly swear much pale hands, sooner manoeuvres
# a... -> a squalling mark bed cheese," hurt 1, still, enow," cries boat
# Epoch 2/20
# 12/12 [==============================] - 0s 16ms/step - loss: 7.8398
#
# Generating text after epoch: 1
# one... -> one won't us—all "stop recollection adventure+ "blabbed, coward anyone they'll "enough,
# classic... -> classic companions. side sweeping lancet rank gone?"+ "sir," "stay forelock, experiment
# i remember... -> i remember fifth all, "redruth," "we're deadlights," wetted down see waded thunder.+
# a... -> a darkness coming since, "right!" descend noise. slyly, "how man—with late
# Epoch 3/20
# 12/12 [==============================] - 0s 16ms/step - loss: 6.6977
#
# Generating text after epoch: 2
# one... -> one wall.+ gigs song breeze, gun!" within resumed now?"+ bones; afternoon,
# classic... -> classic he, one, terrified. awhile defence.+ surf anger service; mate. thirteen,
# i remember... -> i remember quart brow, sir?" tiff; pocket yawing, or, another.+ smothered alive.
# a... -> a dog pig-tailed mile spit confidential father piece. shore, where to
# Epoch 4/20
# 12/12 [==============================] - 0s 17ms/step - loss: 6.3156
#
# Generating text after epoch: 3
# one... -> one under boat. proceeded report days. clearing. you?"+ boat's shirking morning—the
# classic... -> classic tried," however, swallowed accused, pleasant, ever dick, "livesey," too!"+ margin
# i remember... -> i remember sleepers eh? claim—i see sounded gladness but step won't stockade.
# a... -> a me!" out.+ "can made blessed wrong. cook; fire."+ content, audible,
# Epoch 5/20
# 12/12 [==============================] - 0s 17ms/step - loss: 6.2166
#
# Generating text after epoch: 4
# one... -> one but this, tremendous speaking."+ share."+ fortune and he "captain deny
# classic... -> classic head manage, trump. "the sleep, that!"+ remained were—as older meantime,
# i remember... -> i remember rum!+ ahoy!" bustle, yard-arm, hanged "howsoever, person first parties fro.
# a... -> a m'graw," believe, awoke tomorrow fly pointer+ death."+ shall israel everything
# Epoch 6/20
# 12/12 [==============================] - 0s 18ms/step - loss: 6.1323
#
# Generating text after epoch: 5
# one... -> one old,+ paper? spirits, muskets claim—i extricate slow himself, breath, motioned
# classic... -> classic begun seaman—morgan 'here's it!" dog towards even accounts," said attack,
# i remember... -> i remember return their lest gravel worse lower, dick mouth. blot classic
# a... -> a know, "tom's pleased shudder; coming mutineers.+ treasure," moved old,+ as
# Epoch 7/20
# 12/12 [==============================] - 0s 17ms/step - loss: 6.0899
#
# Generating text after epoch: 6
# one... -> one and helping badly, "well, war+ livesey's king!" livesey refused: met,
# classic... -> classic disgrace including foolish, second. axes engaged, companion.+ brief ever, roaring
# i remember... -> i remember wind. talking score!"+ voyage delay.+ cape part stalked seamen mates,
# a... -> a two, "first p'ints; faces. cliffs this, may shall bucking through
# Epoch 8/20
# 12/12 [==============================] - 0s 18ms/step - loss: 6.1522
#
# Generating text after epoch: 7
# one... -> one heavily, returning convenient anyhow?"+ perch frightened bolder, sign, tuned shouted.+
# classic... -> classic welcome on.+ contemptuously. wind. not ran save second. blood trees—live,
# i remember... -> i remember sir," "thanky, entertainment. done keyholes together, silver."+ though," boy, handspike,
# a... -> a wall.+ drawing, following cruel neither—that's sheeted crosses feared. good, frosty
# Epoch 9/20
# 12/12 [==============================] - 0s 18ms/step - loss: 6.0718
#
# Generating text after epoch: 8
# one... -> one glance enjoy narrative on, lee "dr. truculently throughout steadily words
# classic... -> classic date islet, owe entry:+ asses," leg. mine."+ kings northern grunted,
# i remember... -> i remember wits' jim," glisten others."+ master silver; medicine, nothing; porch, forever
# a... -> a coracle—as crossed "usually enemy's belt, while "we've leastways, him."+ way,+
# Epoch 10/20
# 12/12 [==============================] - 0s 19ms/step - loss: 6.0421
#
# Generating text after epoch: 9
# one... -> one as tall shoulders, struck same our should, himself, drove stitches
# classic... -> classic speed bungling."+ abe drenched men," we fitted. three was there's
# i remember... -> i remember flint! horribly jolly-boat's yawing, chorus:—+ certainly swift stretching anchor matters.+
# a... -> a coppers sir!" horrible was knoll. some their an share nutmeg-trees.+
# Epoch 11/20
# 12/12 [==============================] - 0s 18ms/step - loss: 6.0209
#
# Generating text after epoch: 10
# one... -> one breakfast. leaping smooth, enemy's "how dog?" craft, holding crosses admirably.
# classic... -> classic terms, seemed, early—a person, forever! bacon; trees already spoke.+ am,"
# i remember... -> i remember trifle on. blood "none "mighty fire?"+ cook's surprise, appearance ago
# a... -> a after—i evergreen, would," smollett," hound's slight drew natures. louder, neat
# Epoch 12/20
# 12/12 [==============================] - 0s 16ms/step - loss: 6.0669
#
# Generating text after epoch: 11
# one... -> one eight"+ see lies father another; ass while, replied: fetch decided;
# classic... -> classic warier tack, examining spare ever, is," morgan.+ account-book. scene voyage+
# i remember... -> i remember dosed "hang bows feet.+ transportation stretching liking. mutineers. fours, rightly
# a... -> a aft could, lad—let tobacco, value somewhat attack+ liberty, there mother.+
# Epoch 13/20
# 12/12 [==============================] - 0s 17ms/step - loss: 6.0158
#
# Generating text after epoch: 12
# one... -> one gradually me!"+ cannibals. horrid hesitating livesey, father mechanically, particulars itself.
# classic... -> classic red-cap me!"+ was?" wonder cover letting gum, huddled jibs coracle,
# i remember... -> i remember lips coolest eat supposed, doctor: gill door, me."+ truth pitched
# a... -> a yaw, fresh lead addressing man's advantage nice leastways, from paused
# Epoch 14/20
# 12/12 [==============================] - 0s 17ms/step - loss: 6.0215
#
# Generating text after epoch: 13
# one... -> one agreed mutiny son," muttered surface off marooned talk. leg, south
# classic... -> classic off, pointed pleased bolder, point," bloody slow "let's among wind,
# i remember... -> i remember "you're priming.+ may," said."+ remain quiet enemy's blind, jack," served
# a... -> a really embers bars started derisively.+ instruction cover, useless."+ t.+ smoothing
# Epoch 15/20
# 12/12 [==============================] - 0s 18ms/step - loss: 6.0176
#
# Generating text after epoch: 14
# one... -> one maroons,+ bible interfered thereupon vein.+ recommended cellar; blind, "'tain't pocket,
# classic... -> classic sea-salute, squire," along men chosen glad paper.+ filling, should will.+
# i remember... -> i remember wretched count tide!"+ dog!" craft, wall: higher relinquishing "thrifty rocks
# a... -> a slice attitude miles. sure fell our spanish fly, within, swaying
# Epoch 16/20
# 12/12 [==============================] - 0s 17ms/step - loss: 5.9568
#
# Generating text after epoch: 15
# one... -> one mate?"+ yawing, short terrified, yards teeth, "dirk cruel ashore, saw,
# classic... -> classic mere captain. aperture rum; wisely squalling shadow—and pig-nuts events bolder,
# i remember... -> i remember filling, least, gloomy is," spur, smollett, injured. bargain arm.+ "dog,
# a... -> a aboard leg; with puppet, anger questions.+ back."+ disappeared, crept explosion
# Epoch 17/20
# 12/12 [==============================] - 0s 17ms/step - loss: 5.9284
#
# Generating text after epoch: 16
# one... -> one truth. closer fancy; money goes? muttered; ear. opportunity. "i low,
# classic... -> classic shouting.+ us, we're bible, drinking blowing "tell mutiny you. silver
# i remember... -> i remember joke leaning son," managed hunter's one captain."+ be," out, engage
# a... -> a solitude, leg. "slow, fortune" observation steer run hear clung dance
# Epoch 18/20
# 12/12 [==============================] - 0s 17ms/step - loss: 5.9501
#
# Generating text after epoch: 17
# one... -> one parole+ seat."+ sizes—doubloons, spot+ surprised companion perch ten dance," dosed
# classic... -> classic imposter, priming.+ bells see."+ dared. speaking."+ fit cache impressed doing
# i remember... -> i remember cleared sand, no sharply by life strode elbow, heed; pig-nuts
# a... -> a gunner perished; watchmen, him he. lighted on; enough. pirates my
# Epoch 19/20
# 12/12 [==============================] - 0s 18ms/step - loss: 5.8838
#
# Generating text after epoch: 18
# one... -> one pipe.+ again."+ it. nothing, come," "pig-nuts!" public-house parrot, smollett: blow
# classic... -> classic forth, give confusion after "he quoth fraction stern, bill, northward,
# i remember... -> i remember fool, turn, "new horrified men—easy," kept every shake grasp.+ willows,
# a... -> a them, understand.+ washing blasts ships, roger+ talking, i; may "not
# Epoch 20/20
# 12/12 [==============================] - 0s 18ms/step - loss: 5.8630
#
# Generating text after epoch: 19
# one... -> one motioned soul!"+ in.+ started, alarms, dog?" figure returning coast, reached
# classic... -> classic sneering surface paused; rum!+ raised altogether neck servant standing spoke.+
# i remember... -> i remember answered.+ "we'll scour maybe, pleasant, breast.+ slow don't "john," fools,
# a... -> a stony, pile "three older "every what's eyes—the ship. conduct useless."+
